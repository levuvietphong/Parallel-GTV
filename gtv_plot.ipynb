# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from utils import *
from gtv import *

# %%
# load data and compute covariance matrix
X = pd.read_csv('data/X_obs.csv').values
y = pd.read_csv('data/ygroup_avg.csv').values.reshape(1,-1)[0]
Xlens = pd.read_csv('data/X_lens.csv').values
fts = pd.read_csv('data/sst_columns.csv')

Slens = Xlens.T@Xlens/Xlens.shape[0]
Dlens = edge_incidence(Slens, .5) # we threshold the covariance matrix at .5

# split data into train/test
X_train = X[:50]
y_train = y[:50]
X_test = X[50:]
y_test = y[50:]

# %%
df = pd.read_csv('Florida_res.csv')
draw_lambda_contour(df.round(6), 'r2', vmin=-.45, vmax=.45)
ind=df['r2'].argmax()
lambda1_max = df['lambda_1'][ind]
lambdatv_max = df['lambda_tv'][ind]
print(lambda1_max,lambdatv_max,df['r2'][ind])
# Out:
# 0.00505149494949495 1e-05 0.34276731031581176

# %%
beta = gtv_cvx(X_train, y_train, Dlens, lambda_lasso=lambda1_max, lambda_tv=lambdatv_max, alpha=.9)
# plot the solution
fts['coef'] = beta/2
plot_coefs(fts)

# %%
df = pd.read_csv('Northwest_res.csv')
draw_lambda_contour(df.round(6), 'r2', vmin=-.45, vmax=.45)
ind=df['r2'].argmax()
lambda1_max = df['lambda_1'][ind]
lambdatv_max = df['lambda_tv'][ind]
print(lambda1_max,lambdatv_max,df['r2'][ind])
# Out:
# 0.0001 0.023299518105153717 0.121337907215467

# %%
beta = gtv_cvx(X_train, y_train, Dlens, lambda_lasso=lambda1_max, lambda_tv=lambdatv_max, alpha=.9)
# plot the solution
fts['coef'] = beta/2
plot_coefs(fts)
# Out:
# /Users/phong/miniconda3/envs/gtv2/lib/python3.6/site-packages/cvxpy/problems/problem.py:1061: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   "Solution may be inaccurate. Try another solver, "

# %%
df = pd.read_csv('SWUS_res.csv')
draw_lambda_contour(df.round(6), 'r2', vmin=-.45, vmax=.45)
ind=df['r2'].argmax()
lambda1_max = df['lambda_1'][ind]
lambdatv_max = df['lambda_tv'][ind]
print(lambda1_max,lambdatv_max,df['r2'][ind])
# Out:
# 0.0101019898989899 0.0004291934260128778 0.4520607705968025

# %%
beta = gtv_cvx(X_train, y_train, Dlens, lambda_lasso=lambda1_max, lambda_tv=lambdatv_max, alpha=.9)
# plot the solution
fts['coef'] = beta/2
plot_coefs(fts)
# Out:
# /Users/phong/miniconda3/envs/gtv2/lib/python3.6/site-packages/cvxpy/problems/problem.py:1061: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   "Solution may be inaccurate. Try another solver, "
